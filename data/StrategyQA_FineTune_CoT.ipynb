# %% [markdown]
# # StrategyQA — Fine‑Tune CoT (Teacher→Student) **Exactly like the article**
#
# **What this notebook does (faithful to Fine‑Tune‑CoT):**
# - Uses a **teacher LLM** to generate *reasoning (CoT) + a final “Yes/No”* for each question.
# - **Filters** examples where the teacher’s `Final:` matches the gold label.
# - **Fine‑tunes your student model** so that **input = question** and **target/output = rationale + `Final: Yes/No`**.
# - At inference, the student gets **only the question** and must **produce reasoning and a final answer**.
#
# > This is the canonical Fine‑tune‑CoT setup from the article/paper (rationale as supervision, not as input).

# %%
# !pip install -q datasets transformers openai bitsandbytes accelerate python-dotenv huggingface_hub huggingface_hub[hf_xet]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.2 MB/s eta 0:00:00

# %%
# === CONFIG ===
# >>>> Put your student model here (HF Hub id or local path) <<<<
BASE_MODEL = "microsoft/phi-2"  # change to the student model you use

# Teacher settings (OpenAI by default; you can add your provider)
TEACHER_PROVIDER = "openai"   # options: "openai", "dummy"
TEACHER_MODEL = "gpt-4o-mini" # cheaper GPT-4 class; change to your choice
TEMPERATURE = 0.2
MAX_TEACHER_TOKENS = 400

# Data and training
SEED = 42
MAX_TRAIN_SAMPLES = 2000   # sub-sample to control budget
MAX_SEQ_LEN = 192          # token budget for student training (input + output kept short)
EPOCHS = 3
LR = 2e-4
BATCH_SIZE = 8

# Paths
DATA_DIR = "data/strategyqa"
TRAIN_JSON = f"{DATA_DIR}/train.jsonl"
DEV_JSON   = f"{DATA_DIR}/dev.jsonl"
OUT_DIR = "out/cot_student"
OUT_DIR_ASK = "out/cot_student_ask"
TEACHER_DUMP = f"{DATA_DIR}/train_teacher_dump.jsonl"
SFT_JSONL = f"{DATA_DIR}/train_sft_cot.jsonl"   # input=question, output=rationale+Final
PRED_JSON = f"{OUT_DIR}/dev_preds.json"

# Config (reuses your globals when present)
STUDENT_DRAFT_MODEL = TEACHER_MODEL          # you can set a different model if you want
DEV_FRAC_STUDENTQ = 0.1                      # 10% of kept rows go to dev
TEACHER_DUMP_STUDENTQ = f"{DATA_DIR}/teacher_dump_studentq.jsonl"
SFT_STUDENTQ_TRAIN = f"{DATA_DIR}/train_sft_cot_studentq.jsonl"
SFT_STUDENTQ_DEV   = f"{DATA_DIR}/dev_sft_cot_studentq.jsonl"



# Auth (if needed)
# %env HF_TOKEN=
# %env OPENAI_API_KEY= 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
# Out:
# env: OPENAI_API_KEY=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

# %%
# If running on Colab or a fresh env, uncomment:
# !pip install -q transformers==4.43.3 peft==0.12.0 datasets accelerate bitsandbytes tiktoken openai==1.35.10

# %%
import os, json, random, re, time, math, pathlib
from dataclasses import dataclass
from typing import Dict, List, Any

import torch
from transformers import (AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer)
from peft import LoraConfig, get_peft_model, TaskType

random.seed(SEED)

# Robust final-line parser: look for a line 'Final: Yes/No'
FINAL_RE = re.compile(r"^\s*final\s*:\s*(yes|no)\s*$", re.IGNORECASE | re.MULTILINE)

# Accepts: "Final: Yes", "Final: No", "Final answer: Yes", "Final answer: No"
# Allows punctuation/words after Yes/No, and matches anywhere in the text.
FINAL_RE = re.compile(
    r"(?im)\bfinal(?:\s*answer)?\s*[:\-–]\s*(yes|no)\b"
)

def extract_final(text: str) -> str:
    if not text:
        return ""
    # prefer the LAST occurrence in case multiple appear
    last = None
    for m in FINAL_RE.finditer(text):
        last = m
    if last:
        yn = last.group(1).strip().lower()
        return "Yes" if yn.startswith("y") else "No"
    # fallback: if "final" appears near the end, try heuristics
    tail = (text[-200:] or "").lower()
    if "final" in tail:
        if " yes" in tail or "yes" in tail:
            return "Yes"
        if " no" in tail or "no" in tail:
            return "No"
    return ""

PROMPT_TMPL = (
    "You are a careful reasoner. Solve the yes/no question step-by-step.\n"
    "Then output \"Final: Yes\" or \"Final: No\".\n\n"
    "Q: {q}\nReasoning:\n"
)

# %%
# This cell expects local StrategyQA jsonl files at data/strategyqa/{train,dev}.jsonl
# Each line: {"question": "...", "answer": "Yes/No"}
# If not present, we create a tiny demo split to let the notebook run end-to-end.

path_train = pathlib.Path(TRAIN_JSON)
path_dev   = pathlib.Path(DEV_JSON)
os.makedirs(DATA_DIR, exist_ok=True)

if not (path_train.exists() and path_dev.exists()):
    print("[WARN] Local StrategyQA not found. Creating a tiny demo set (10 train, 5 dev).")
    toy_train = [
        {"question":"Is water wet?", "answer":"Yes"},
        {"question":"Is 2 greater than 3?", "answer":"No"},
        {"question":"Do birds have wings?", "answer":"Yes"},
        {"question":"Is the Sun a planet?", "answer":"No"},
        {"question":"Can penguins fly?", "answer":"No"},
        {"question":"Is Peru in South America?", "answer":"Yes"},
        {"question":"Does the Amazon River flow through Peru?", "answer":"Yes"},
        {"question":"Is 10 an even number?", "answer":"Yes"},
        {"question":"Do spiders have six legs?", "answer":"No"},
        {"question":"Is Earth flat?", "answer":"No"},
    ]
    toy_dev = [
        {"question":"Is the Nile a river?", "answer":"Yes"},
        {"question":"Is zero a negative number?", "answer":"No"},
        {"question":"Do fish breathe air with lungs?", "answer":"No"},
        {"question":"Is Mount Everest the tallest mountain on Earth?", "answer":"Yes"},
        {"question":"Is chocolate salty by default?", "answer":"No"},
    ]
    with open(TRAIN_JSON, "w", encoding="utf-8") as f:
        for r in toy_train: f.write(json.dumps(r)+"\n")
    with open(DEV_JSON, "w", encoding="utf-8") as f:
        for r in toy_dev: f.write(json.dumps(r)+"\n")

train_rows = [json.loads(l) for l in open(TRAIN_JSON, encoding="utf-8")]
dev_rows   = [json.loads(l) for l in open(DEV_JSON, encoding="utf-8")]

print(f"[OK] Train rows: {len(train_rows)} | Dev rows: {len(dev_rows)}")
# Out:
# [WARN] Local StrategyQA not found. Creating a tiny demo set (10 train, 5 dev).
# [OK] Train rows: 10 | Dev rows: 5

# %%
def call_teacher_llm(prompt: str) -> str:
    if TEACHER_PROVIDER == "dummy":
        final = "Yes" if random.random() < 0.5 else "No"
        return "Because of common knowledge.\nFinal: " + final  # newline before Final
    elif TEACHER_PROVIDER == "openai":
        from openai import OpenAI
        api_key = os.getenv("OPENAI_API_KEY")
        if not api_key:
            raise RuntimeError("Please set OPENAI_API_KEY env var for teacher generation.")
        client = OpenAI(api_key=api_key)
        resp = client.chat.completions.create(
            model=TEACHER_MODEL,
            temperature=TEMPERATURE,
            messages=[
                {"role":"system","content":
                  "Answer ONE yes/no question. Use 1–3 brief steps, then EXACTLY one line: 'Final: Yes' or 'Final: No'. "
                  "No extra questions, no examples, keep ≤80 tokens total."},
                # {"role": "system", "content":
                #  "Answer ONE yes/no question. Show brief step-by-step reasoning, then on a new line write EXACTLY one of: 'Final: Yes' or 'Final: No'. "
                #  "Do NOT include extra examples, exercises, or additional questions."},
                {"role": "user", "content": prompt},
            ],
            max_tokens=MAX_TEACHER_TOKENS,
            stop=["\n\nQ:", "\nQ:"]   # <- prevent starting another question
        )
        return resp.choices[0].message.content.strip()
    else:
        raise ValueError(f"Unknown TEACHER_PROVIDER: {TEACHER_PROVIDER}")

# %%
FINAL_LINE_RE = re.compile(r"^\s*Final:\s*(Yes|No)\s*$", re.IGNORECASE | re.MULTILINE)

def sanitize_teacher_old(text: str) -> str:
    """
    Keep reasoning up to and including the FIRST 'Final:' line.
    Drop anything after (examples, extra Q:, etc).
    Also normalize 'Final: yes/no' casing.
    """
    if not text:
        return ""
    # Find first Final line
    m = FINAL_LINE_RE.search(text)
    if not m:
        return ""
    end = m.end()
    head = text[:end]
    # Normalize the final line to 'Final: Yes' or 'Final: No'
    final_norm = f"Final: {'Yes' if m.group(1).lower().startswith('y') else 'No'}"
    # Replace the matched segment's final line with normalized version
    head = FINAL_LINE_RE.sub(final_norm, head)
    return head.strip()

MAX_COT_TOKENS = 96  # keep short

def sanitize_teacher(text: str) -> str:
    if not text:
        return ""
    m = FINAL_LINE_RE.search(text)
    if not m:
        return ""
    head = text[:m.end()]
    head = FINAL_LINE_RE.sub(f"Final: {'Yes' if m.group(1).lower().startswith('y') else 'No'}", head)
    # Hard trim to avoid rambling before Final:
    head = head.split("\nQ:")[0].split("\n\nQ:")[0]  # kill accidental next prompts
    # Optional: coarse token cap (char cap is fine here since we’re pre-tokenizer)
    return head.strip()[:800]  # ~800 chars ≈ << MAX_COT_TOKENS tokens on average


def normalize_label(s) -> str:
    # Handle boolean values directly
    if isinstance(s, bool):
        return "Yes" if s else "No"

    # Convert non-bool to string for processing
    s = str(s).strip().lower()
    if s.startswith("y"):
        return "Yes"
    if s.startswith("n"):
        return "No"
    return "Yes" if s in {"true", "1"} else "No"

# %%
# Build SFT dataset exactly as in Fine-tune-CoT:
# input = question
# output = teacher rationale + 'Final: Yes/No'
# Keep only examples where Final == gold answer.


# Subsample for budget

train_rows = [json.loads(l) for l in open(TRAIN_JSON, encoding="utf-8")]


rows = train_rows[:]
random.shuffle(rows)
if MAX_TRAIN_SAMPLES and len(rows) > MAX_TRAIN_SAMPLES:
    rows = rows[:MAX_TRAIN_SAMPLES]

kept = 0
with open(TEACHER_DUMP, "w", encoding="utf-8") as dump_f,      open(SFT_JSONL, "w", encoding="utf-8") as sft_f:

    for r in rows:
        q = r["question"].strip()
        gold = normalize_label(r["answer"])
        prompt = PROMPT_TMPL.format(q=q)

        # try a couple of times to get a 'Final:' line
        raw = call_teacher_llm(prompt)
        out = sanitize_teacher(raw)
        final = extract_final(out)
        dump_f.write(json.dumps({"question": q, "gold": gold, "teacher_full": raw}, ensure_ascii=False) + "\n")

        if final and final == gold:
            sft_f.write(json.dumps({"input": q, "output": out}, ensure_ascii=False) + "\n")
            kept += 1


print(f"[STAT] Kept training examples after filtering: {kept}")
print(f"[OK] Wrote teacher dump: {TEACHER_DUMP}")
print(f"[OK] Wrote SFT jsonl:   {SFT_JSONL}")

# After writing SFT_JSONL:
print("SFT size:", sum(1 for _ in open(SFT_JSONL, "r", encoding="utf-8")))
for i, line in zip(range(3), open(SFT_JSONL, "r", encoding="utf-8")):
    ex = json.loads(line)
    print("SFT SAMPLE", i, "INPUT:", ex["input"])
    print("SFT SAMPLE", i, "OUTPUT:", ex["output"])
    print("----")
# Out:
# [STAT] Kept training examples after filtering: 801
# [OK] Wrote teacher dump: data/strategyqa/train_teacher_dump.jsonl
# [OK] Wrote SFT jsonl:   data/strategyqa/train_sft_cot.jsonl
# SFT size: 801
# SFT SAMPLE 0 INPUT: If a baby was born on Halloween would they be a Scorpio?
# SFT SAMPLE 0 OUTPUT: 1. Halloween is on October 31.
# 2. Scorpio is from October 23 to November 21.
# 3. A baby born on Halloween falls within the Scorpio date range.
# Final: Yes
# ----
# SFT SAMPLE 1 INPUT: Is a slime mold safe from cerebral palsy?
# SFT SAMPLE 1 OUTPUT: 1. Slime molds are single-celled organisms and do not have a nervous system or brain.
# 2. Cerebral palsy is a neurological disorder affecting humans, specifically their motor functions.
# 3. Since slime molds are not human and do not have a nervous system, they cannot be affected by cerebral palsy.
# Final: Yes
# ----
# SFT SAMPLE 2 INPUT: Does the word swastika have meaning in sanskrit?
# SFT SAMPLE 2 OUTPUT: 1. The word "swastika" originates from the Sanskrit word "svastika," which means "well-being" or "good fortune."
# 2. It is a symbol used in various cultures, including Hinduism and Buddhism, with positive connotations.
# 3. Therefore, the word does have meaning in Sanskrit.
# Final: Yes
# ----

# %%
# === Build SFT with student-questions -> teacher-CoT ===
# Produces:
#   data/strategyqa/train_sft_cot_studentq.jsonl
#   data/strategyqa/dev_sft_cot_studentq.jsonl

import os, json, random, re, pathlib
from collections import Counter

random.seed(SEED)

def _openai_chat(messages, model, temperature, max_tokens=400, stop=None):
    from openai import OpenAI
    api_key = os.getenv("OPENAI_API_KEY")
    if not api_key:
        raise RuntimeError("Set OPENAI_API_KEY to use provider='openai'")
    client = OpenAI(api_key=api_key)
    resp = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
        stop=stop
    )
    return resp.choices[0].message.content.strip()

def gen_student_draft(q: str) -> str:
    """
    Return a STRICTLY formatted student draft for a yes/no question.

    Output format (exactly two lines):
        Answer: <Yes/No>
        Questions: <Q1>? <Q2>?

    - Tries up to 3 times to get a clean response from the student model.
    - Enforces casing ('Yes'/'No'), exactly two questions ending with '?',
      and removes any extra content.
    - Falls back to a minimal valid draft if formatting fails.

    Depends on:
      - TEACHER_PROVIDER ("openai" or "dummy")
      - STUDENT_DRAFT_MODEL (model string for _openai_chat)
      - _openai_chat(messages, model, temperature, max_tokens, stop)
    """
    import re, random

    # Strict validator: "Answer: Yes|No" + "Questions: ...? ...?"
    # Allows extra whitespace but requires 1–2 questions ending with '?'
    DRAFT_RE = re.compile(
        r"(?is)^\s*answer\s*:\s*(yes|no)\s*\n\s*questions\s*:\s*(.+\?)\s*(.+\?)?\s*$"
    )

    def _normalize_and_fix(raw: str) -> str:
        """Coerce to the exact two-line format; clip to at most two questions."""
        if not raw:
            return ""

        raw = raw.strip()

        # Pull "Answer: ..." (Yes/No) robustly
        m_ans = re.search(r"(?is)^\s*answer\s*:\s*(yes|no)\b", raw)
        ans = m_ans.group(1).strip().lower() if m_ans else ""
        ans = "Yes" if ans.startswith("y") else ("No" if ans.startswith("n") else "")

        # Pull the questions line
        m_qs = re.search(r"(?is)questions\s*:\s*(.*)$", raw)
        qs_raw = m_qs.group(1).strip() if m_qs else ""

        # Split on '?' and keep the first two non-empty fragments, then append '?'
        parts = [p.strip() for p in qs_raw.split("?") if p.strip()]
        parts = parts[:2] if parts else []

        # If fewer than 2 valid questions, synthesize generic but relevant ones
        while len(parts) < 2:
            if len(parts) == 0:
                parts.append(f"What key facts determine the answer to '{q[:80]}'")
            else:
                parts.append("Are there any known exceptions or edge cases")

        # Ensure each ends with '?'
        q1 = (parts[0] + "?").replace("??", "?")
        q2 = (parts[1] + "?").replace("??", "?")

        if not ans:
            return ""

        return f"Answer: {ans}\nQuestions: {q1} {q2}"

    if TEACHER_PROVIDER == "dummy":
        yn = "Yes" if random.random() < 0.5 else "No"
        q1 = f"What facts are required to verify '{q[:80]}'?"
        q2 = "Do timelines or definitions change the outcome?"
        return f"Answer: {yn}\nQuestions: {q1} {q2}"

    elif TEACHER_PROVIDER == "openai":
        sys = (
            "You are a careful student. For the ONE yes/no question, propose a tentative answer "
            "and ask 1–2 short clarifying sub-questions to verify it.\n"
            "Respond in EXACTLY this format (two lines only):\n"
            "Answer: <Yes/No>\n"
            "Questions: <Q1>? <Q2>?\n"
            "Rules: No extra text before/after. Keep questions compact (≤12 words each)."
        )

        # Up to 3 attempts to get clean format; slightly higher temperature for better drafts
        for _ in range(2):
            draft = _openai_chat(
                [{"role": "system", "content": sys},
                 {"role": "user",   "content": f"Q: {q}"}],
                model=STUDENT_DRAFT_MODEL,
                temperature=0.5,
                max_tokens=120,
                stop=None
            )

            fixed = _normalize_and_fix(draft)
            if fixed and DRAFT_RE.match(fixed):
                return fixed

        # Final fallback (guaranteed-valid)
        return fixed

    else:
        raise ValueError(f"Unknown TEACHER_PROVIDER={TEACHER_PROVIDER}")

def gen_teacher_cot(q: str, student_draft: str) -> str:
    """Teacher CoT that explicitly references student's questions; must end with 'Final: Yes/No'."""
    if TEACHER_PROVIDER == "dummy":
        yn = "Yes" if random.random() < 0.5 else "No"
        return f"1) Address sub-questions.\n2) Conclude based on timelines.\nFinal: {yn}"
    elif TEACHER_PROVIDER == "openai":
        sys = (
            "You are the TEACHER. Use the student's sub-questions to structure a brief, factual chain-of-thought. "
            "Address each student sub-question explicitly; then write EXACTLY one line: 'Final: Yes' OR 'Final: No'. "
            "Do NOT add other questions or extra examples."
        )
        user = (
            f"Original question:\n{q}\n\n"
            f"Student draft:\n{student_draft}\n\n"
            "Write step-by-step reasoning that references the student's questions, then a single final line."
        )
        return _openai_chat(
            [{"role":"system","content":sys},{"role":"user","content":user}],
            model=TEACHER_MODEL,
            temperature=0.2,
            max_tokens=min(300, MAX_TEACHER_TOKENS),
            stop=["\n\nQ:", "\nQ:"]   # prevent new QA blocks
        )
    else:
        raise ValueError(f"Unknown TEACHER_PROVIDER={TEACHER_PROVIDER}")

# ---- Build the new SFT ----
in_path = pathlib.Path(TRAIN_JSON)
assert in_path.exists(), f"Missing {TRAIN_JSON}"
src_rows = [json.loads(l) for l in open(TRAIN_JSON, encoding="utf-8")]

rows = src_rows[:]
random.shuffle(rows)
if MAX_TRAIN_SAMPLES and len(rows) > MAX_TRAIN_SAMPLES:
    rows = rows[:MAX_TRAIN_SAMPLES]

kept = []
dropped_no_final = 0
dropped_mismatch = 0
with open(TEACHER_DUMP_STUDENTQ, "w", encoding="utf-8") as dump_f:
    for r in rows:
        q = r["question"].strip()
        gold = normalize_label(r["answer"])

        student_draft = gen_student_draft(q)
        raw_cot = gen_teacher_cot(q, student_draft)
        cot = sanitize_teacher(raw_cot)
        final = extract_final(cot)

        print(f"the q: {q}\n the gold: {gold}\n the student: {student_draft}\n and the teacher cot: {cot} \n")

        dump_f.write(json.dumps({
            "question": q,
            "gold": gold,
            "student_draft": student_draft,
            "teacher_full": raw_cot
        }, ensure_ascii=False) + "\n")

        if not final:
            dropped_no_final += 1
            continue
        if final != gold:
            dropped_mismatch += 1
            continue

        kept.append({
            "input": q,                # train input stays the original question
            "student_draft": student_draft,  # stored for analysis/debug (not used as input)
            "output": cot              # teacher CoT that references student's questions + 'Final: ...'
        })

print(f"[BUILD] kept={len(kept)}  dropped_no_final={dropped_no_final}  dropped_mismatch={dropped_mismatch}")

# ---- Stratified dev split by parsed label ----
yes = [x for x in kept if extract_final(x["output"]) == "Yes"]
no  = [x for x in kept if extract_final(x["output"]) == "No"]
random.shuffle(yes); random.shuffle(no)

total = len(kept)
dev_n = max(1, int(round(total * DEV_FRAC_STUDENTQ)))
dev_yes_n = int(round(dev_n * len(yes) / max(1, total)))
dev_no_n  = dev_n - dev_yes_n

dev = yes[:dev_yes_n] + no[:dev_no_n]
train = yes[dev_yes_n:] + no[dev_no_n:]
random.shuffle(dev); random.shuffle(train)

with open(SFT_STUDENTQ_TRAIN, "w", encoding="utf-8") as f:
    for o in train: f.write(json.dumps(o, ensure_ascii=False) + "\n")
with open(SFT_STUDENTQ_DEV, "w", encoding="utf-8") as f:
    for o in dev: f.write(json.dumps(o, ensure_ascii=False) + "\n")

print(f"[WRITE] train={len(train)}  dev={len(dev)}")
print("[DEV LABEL COUNTS]", Counter(extract_final(o["output"]) for o in dev))

# ---- Peek a few samples ----
for i, o in enumerate(dev[:3]):
    print("==== SAMPLE", i)
    print("Q:", o["input"])
    print("STUDENT_DRAFT:\n", o["student_draft"])
    print("TEACHER_COT:\n", o["output"])
    print("------------------------")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-3413970370.py in <cell line: 0>()
#      81 # ---- Build the new SFT ----
#      82 in_path = pathlib.Path(TRAIN_JSON)
# ---> 83 assert in_path.exists(), f"Missing {TRAIN_JSON}"
#      84 src_rows = [json.loads(l) for l in open(TRAIN_JSON, encoding="utf-8")]
#      85
#
# AssertionError: Missing data/strategyqa/train.jsonl

# %%
import json, random
from collections import Counter

random.seed(42)

SRC = "data/strategyqa/train_sft_cot.jsonl"  # path to your 790-sample file
DEV_OUT = "data/strategyqa/dev_sft_cot.jsonl"
TRAIN_OUT = "data/strategyqa/train_sft_cot_reduced.jsonl"

DEV_N = 100  # how many you want for dev
DEV_FRAC = 0.1

# ====== Load & parse ======
rows = []
with open(SRC, "r", encoding="utf-8") as f:
    for line in f:
        o = json.loads(line)
        o_out = o.get("output", "")
        label = extract_final(o_out)
        if label in ("Yes", "No"):
            rows.append({"input": o["input"], "output": o_out, "answer": label})
        # If no label found, drop the row silently (can log if you want)

print(f"[LOAD] total rows read: {len(rows)}")
print("[LABEL COUNTS]", Counter(r["answer"] for r in rows))

# ====== Compute dev size ======
total = len(rows)
if DEV_N is None:
    DEV_N = max(1, int(round(total * DEV_FRAC)))
DEV_N = min(DEV_N, total - 1)  # leave at least one for train

# ====== Stratified split by label ======
yes = [r for r in rows if r["answer"] == "Yes"]
no  = [r for r in rows if r["answer"] == "No"]
random.shuffle(yes); random.shuffle(no)

# Proportional allocation
dev_yes_n = int(round(DEV_N * len(yes) / max(1, total)))
dev_no_n  = DEV_N - dev_yes_n

dev = yes[:dev_yes_n] + no[:dev_no_n]
train = yes[dev_yes_n:] + no[dev_no_n:]
random.shuffle(dev); random.shuffle(train)

# ====== Save (drop the helper 'answer' field to keep original schema if you prefer) ======
with open(DEV_OUT, "w", encoding="utf-8") as f:
    for r in dev:
        f.write(json.dumps({"input": r["input"], "output": r["output"]}, ensure_ascii=False) + "\n")

with open(TRAIN_OUT, "w", encoding="utf-8") as f:
    for r in train:
        f.write(json.dumps({"input": r["input"], "output": r["output"]}, ensure_ascii=False) + "\n")

print(f"[SPLIT] train={len(train)}  dev={len(dev)}")
print("[DEV LABEL COUNTS]", Counter(extract_final(r["output"]) for r in dev))
print("[TRAIN LABEL COUNTS]", Counter(extract_final(r["output"]) for r in train))
# Out:
# [LOAD] total rows read: 801
# [LABEL COUNTS] Counter({'No': 483, 'Yes': 318})
# [SPLIT] train=701  dev=100
# [DEV LABEL COUNTS] Counter({'No': 60, 'Yes': 40})
# [TRAIN LABEL COUNTS] Counter({'No': 423, 'Yes': 278})

# %%
import torch, os
torch.cuda.empty_cache()
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
class CoTDataset(torch.utils.data.Dataset):
    def __init__(self, jsonl_path, tokenizer, max_len=MAX_SEQ_LEN):
        self.rows = [json.loads(l) for l in open(jsonl_path, encoding="utf-8")]
        self.tok = tokenizer
        self.max_len = max_len

    def __len__(self): return len(self.rows)

    def __getitem__(self, i):
        r = self.rows[i]
        q = r["input"]
        y = r["output"]
        # Pack as: [question] -> [rationale + Final]
        # We'll concatenate and mask so that loss applies to the output tokens only.
        enc_inp = self.tok(q, truncation=True, max_length=self.max_len)
        enc_out = self.tok(y, truncation=True, max_length=self.max_len)

        input_ids = enc_inp["input_ids"] + enc_out["input_ids"]
        # Build labels: ignore index for the input portion
        labels = [-100]*len(enc_inp["input_ids"]) + enc_out["input_ids"]
        if len(input_ids) > self.max_len:
            input_ids = input_ids[:self.max_len]
            labels = labels[:self.max_len]

        return {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "labels": torch.tensor(labels, dtype=torch.long)
        }

# %%
from transformers import BitsAndBytesConfig, AutoTokenizer, AutoModelForCausalLM
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training
import torch

def _detect_lora_targets(model):
    names = [n for n,_ in model.named_modules()]
    # phi-2 family: fused qkv
    if any(n.endswith("Wqkv") or ".Wqkv" in n for n in names):
        return ["Wqkv", "out_proj"]
    # Llama/Mistral
    if any(".q_proj" in n for n in names):
        return ["q_proj", "v_proj"]
    # GPT-2 style
    if any(".c_attn" in n for n in names):
        return ["c_attn", "c_proj"]
    # fallback: try common names
    return ["Wqkv","out_proj","q_proj","v_proj","k_proj","o_proj","c_attn","c_proj"]

def make_model_and_tokenizer():
    tok = AutoTokenizer.from_pretrained(BASE_MODEL, use_fast=True)
    if tok.pad_token is None:
        tok.pad_token = tok.eos_token

    bnb_cfg = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float16,
    )

    model = AutoModelForCausalLM.from_pretrained(
        BASE_MODEL,
        quantization_config=bnb_cfg,
        device_map="auto",
        low_cpu_mem_usage=True,
        trust_remote_code=False,
    )
    model = prepare_model_for_kbit_training(model)

    targets = _detect_lora_targets(model)
    lora_cfg = LoraConfig(
        task_type=TaskType.CAUSAL_LM,
        r=8, lora_alpha=16, lora_dropout=0.05,
        target_modules=targets
    )
    model = get_peft_model(model, lora_cfg)

    model.gradient_checkpointing_enable()
    model.config.use_cache = False

    # sanity
    trainable = [n for n,p in model.named_parameters() if p.requires_grad]
    print(f"Trainable tensors: {len(trainable)}")
    assert len(trainable) > 0, "No trainable parameters — LoRA didn't attach."
    return model, tok

# %%
os.environ["WANDB_DISABLED"] = "true"
os.makedirs(OUT_DIR, exist_ok=True) ##change dir if needed
model, tok = make_model_and_tokenizer()
ds = CoTDataset(TRAIN_OUT, tok, MAX_SEQ_LEN) ##yuval debug - TRAIN_OUT change if needed

args = TrainingArguments(
    output_dir=OUT_DIR,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    learning_rate=LR,
    num_train_epochs=EPOCHS,
    fp16=True,               # or bf16=True if supported
    logging_steps=20,
    save_strategy="epoch",
    report_to="none",        # <- proper way (no WANDB prompt)
    dataloader_num_workers=2
)


trainer = Trainer(model=model, args=args, train_dataset=ds)
trainer.train()
trainer.save_model(OUT_DIR)
tok.save_pretrained(OUT_DIR)

print("[OK] Training complete. Model saved to", OUT_DIR)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/564M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Trainable tensors: 128
#     <div>
#
#       <progress value='264' max='264' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [264/264 20:35, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>1.556900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.958800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.822100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.827900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.729900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.728300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.746300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.743800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.696600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.673600</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.702800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.696900</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.708700</td>
#     </tr>
#   </tbody>
# </table><p>
# [OK] Training complete. Model saved to out/cot_student

# %%
from transformers import StoppingCriteria, StoppingCriteriaList

from transformers import StoppingCriteria, StoppingCriteriaList

class StopOnFinal(StoppingCriteria):
    def __init__(self, tok):
        self.ids_yes = tok.encode("Final: Yes", add_special_tokens=False)
        self.ids_no  = tok.encode("Final: No",  add_special_tokens=False)
    def __call__(self, input_ids, scores, **kwargs):
        seq = input_ids[0].tolist()
        return (len(seq) >= len(self.ids_yes) and seq[-len(self.ids_yes):] == self.ids_yes) or \
               (len(seq) >= len(self.ids_no)  and seq[-len(self.ids_no):]  == self.ids_no)

from transformers import StoppingCriteria, StoppingCriteriaList

def generate_answer(model, tok, q: str) -> str:
    # 1) Prompt exactly like training input (no instruction line to copy)
    prompt = f"Q: {q}\nReasoning:\n"
    enc = tok(prompt, return_tensors="pt", truncation=True, max_length=192)
    enc = {k: v.to(model.device) for k, v in enc.items()}
    prompt_len = enc["input_ids"].shape[1]

    # --- pass 1: generate reasoning; block 'Final:' so it can't jump early ---
    bad_ids_final = [tok.encode("Final:", add_special_tokens=False)]
    bad_qas = [tok.encode(w, add_special_tokens=False) for w in ["\nQ:", "\n\nQ:", "\nA:", "\n\nA:"]]
    bad_words_ids = bad_ids_final + bad_qas

    with torch.inference_mode():
        out1 = model.generate(
            **enc,
            max_new_tokens=96,
            min_new_tokens=24,         # force some reasoning tokens
            do_sample=False,
            num_beams=1,
            eos_token_id=tok.eos_token_id,
            pad_token_id=tok.eos_token_id,
            bad_words_ids=bad_words_ids,
            no_repeat_ngram_size=3,
            repetition_penalty=1.05,
        )

    # Extract only the newly generated reasoning text
    reasoning = tok.decode(out1[0][prompt_len:], skip_special_tokens=True).strip()

    # 2) Append 'Final:' and let the model decide Yes/No only (tiny decode)
    prompt2 = prompt + (reasoning + "\n" if reasoning else "") + "Final:"
    enc2 = tok(prompt2, return_tensors="pt", truncation=True, max_length=192+96)
    enc2 = {k: v.to(model.device) for k, v in enc2.items()}

    with torch.inference_mode():
        out2 = model.generate(
            **enc2,
            max_new_tokens=3,          # just ' Yes' or ' No'
            do_sample=False,
            num_beams=1,
            eos_token_id=tok.eos_token_id,
            pad_token_id=tok.eos_token_id,
        )

    text = tok.decode(out2[0], skip_special_tokens=True)
    final = extract_final(text)
    print(f"first final {final}")
    if not final:
        tl = text.lower()
        final = "Yes" if " final: yes" in tl or tl.strip().endswith("yes") else \
                ("No" if " final: no" in tl or tl.strip().endswith("no") else "No")

    print("---- RAW OUTPUT ----")
    print(text)
    print("--------------------")
    print(f"final answer is: {final}")
    return final

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the target folder inside your Drive
drive_target = '/content/drive/MyDrive/LLM_Models/cot_student_out'
drive_target_ask = '/content/drive/MyDrive/LLM_Models/cot_student_out_ask'
# Out:
# Mounted at /content/drive

# %%
# Copy the OUT_DIR to Drive
import shutil, os
if os.path.exists(OUT_DIR):
    shutil.copytree(OUT_DIR, drive_target, dirs_exist_ok=True)
    print(f"Saved model to: {drive_target}")
else:
    print(f"OUT_DIR '{OUT_DIR}' does not exist!")

if os.path.exists(OUT_DIR_ASK):
    shutil.copytree(OUT_DIR_ASK, drive_target_ask, dirs_exist_ok=True)
    print(f"Saved model to: {drive_target_ask}")
else:
    print(f"OUT_DIR_ASK '{OUT_DIR_ASK}' does not exist!")
# Out:
# Saved model to: /content/drive/MyDrive/LLM_Models/cot_student_out
# OUT_DIR_ASK 'out/cot_student_ask' does not exist!

# %%
# 0) Mount Drive (Colab)
from google.colab import drive
drive.mount('/content/drive')

# 1) Point to the saved model folder on Drive
LOAD_DIR = '/content/drive/MyDrive/LLM_Models/cot_student_out'  # <-- change to your path
PRED_JSON = '/content/drive/MyDrive/LLM_Models/cot_student_out__preds.json'  # optional: save preds to Drive too
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 2) Load tokenizer + PEFT model from Drive
import os, torch, json
from transformers import AutoTokenizer, BitsAndBytesConfig
from peft import AutoPeftModelForCausalLM

# (optional) sanity: show what's in the folder
print("Drive model dir contents:", os.listdir(drive_target_ask)) ## yuval debug - change it to OUT_DIR if you don't want to use the saved model

dev_rows   = [json.loads(l) for l in open(DEV_JSON, encoding="utf-8")]

tok_eval = AutoTokenizer.from_pretrained(drive_target_ask, use_fast=True)
if tok_eval.pad_token_id is None:
    tok_eval.pad_token = tok_eval.eos_token  # ensure padding exists

bnb_cfg_inf = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float16,
)

model_eval = AutoPeftModelForCausalLM.from_pretrained(
    drive_target_ask,
    device_map="auto",
    quantization_config=bnb_cfg_inf,
    torch_dtype="auto"
).eval()

# Fast inference switches (apply AFTER loading)
try:
    model_eval.gradient_checkpointing_disable()
except Exception:
    pass
model_eval.config.use_cache = True

# 3) Run evaluation (fix the denominator if you early-break)
preds, correct, num = [], 0, 0
for r in dev_rows:
    q, gold = r["input"], r["output"]
    gold = extract_final(gold)
    print(f"the q is {q} !! and gold is: {gold}")
    pred = generate_answer(model_eval, tok_eval, q)
    preds.append({"question": q, "pred": pred, "gold": gold})
    correct += int(pred == gold)
    print(f"pred is gold? {pred == gold}")
    num += 1
    if num == 500:   # remove this break if you want full dev
        break

acc = correct / max(1, num)  # <-- use num, not len(dev_rows), when you break
print(f"[DEV ACC] {acc:.3f}  ({correct}/{num})")

with open(PRED_JSON, "w", encoding="utf-8") as f:
    json.dump(preds, f, ensure_ascii=False, indent=2)
print(f"[OK] Wrote predictions to: {PRED_JSON}")
# Out:
# Drive model dir contents: ['checkpoint-76', 'checkpoint-152', 'adapter_model.safetensors', 'tokenizer_config.json', 'checkpoint-228', 'README.md', 'training_args.bin', 'adapter_config.json', 'special_tokens_map.json', 'added_tokens.json', 'tokenizer.json', 'vocab.json', 'merges.txt']
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# the q is Do sun bears stay active during winter? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Do sun bears stay active during winter?
# Reasoning:
# 1. Sun bears are known to be primarily active during the day, which suggests that they may not be as active during nighttime hours.
# 2. Winter is a season characterized by colder temperatures and shorter daylight hours, which could further limit their activity.
# 3. Sun bear behavior is influenced by environmental factors, including temperature and light availability, which would likely affect their activity levels during winter.
# 4. Other bear species, such as polar bears, are adapted to cold environments and
# Final: No, sun
# --------------------
# final answer is: No
# pred is gold? False
# the q is Would downloading Mario 64 on an emulator be legal? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would downloading Mario 64 on an emulator be legal?
# Reasoning:
# 1. The original Mario 64 game was released in 1996 and is protected by copyright laws, which prohibit unauthorized reproduction or distribution of the game.
# 2. Emulators are software programs that simulate a specific gaming system, allowing users to play games from that system on different devices.
# 3. Downloading Mario 64 onto an emulator does not involve creating a physical copy of the original game, as it is being played digitally.
# 4. However, using an emulator to play copyrighted games
# Final: Downloading Mario
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would the average American family find Adam Sandler's home to be too small? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Would the average American family find Adam Sandler's home to be too small?
# Reasoning:
# 1. The average size of a typical American home is around 2,500 square feet.
# 2. Adam Sandlers' home is approximately 1,200 square feet, which is significantly smaller than the average.
# 3. Given that the average size is 2,000 square feet or more, it is reasonable to conclude that most families would find his home too small.
# Final answer: Yes, the average family would find Adam's home too tiny.
# Final reasoning:
# Final: Yes, the
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Would it be typical for a Rede Globo anchor to say Konnichiwa to the viewers? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would it be typical for a Rede Globo anchor to say Konnichiwa to the viewers?
# Reasoning:
# 1. The question is about whether it would be typical, which implies that there is a standard practice or expectation in place.
# 2. RedeGlobo is a Brazilian television network, and Konnigiwa is a Japanese greeting.
# 3. The anchor is typically expected to address the viewers in their native language, which in this case would be Portuguese.
# 4. Therefore, it would not be typical to say "Konnichi wa" as it does not
# Final: No, it
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would keelhauling be a fair punishment under the Eighth Amendment? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would keelhauling be a fair punishment under the Eighth Amendment?
# Reasoning:
# 1. The Eighth Amendment prohibits cruel and unusual punishment, which means that any form of punishment must not cause unnecessary suffering or harm to the individual.
# 2. Keelhaul is a form of physical punishment that involves dragging a person by their hair, causing severe pain and injury. This clearly violates the principle of avoiding unnecessary suffering.
# 3. The practice of keelhawling has been widely condemned as inhumane and barbaric, indicating that it does not align with modern standards of
# Final: No, ke
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would a CEO typically clean the toilets in a company's building? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would a CEO typically clean the toilets in a company's building?
# Reasoning:
# 1. The role of a CEO is to oversee the overall management and operations of a company, including strategic decision-making and leadership responsibilities.
# 2. Cleaning tasks are typically assigned to specific employees or cleaning staff within an organization, rather than being the responsibility of the CEO.
# 3. CEOs often have other pressing matters to attend to, such as meetings, business development, and strategic planning, which would not leave them with sufficient time for toilet cleaning.
# Final answer:
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can someone with celiac disease have potato vodka? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Can someone with celiac disease have potato vodka?
# Reasoning:
# 1. Celiac disease is an autoimmune disorder that requires a strict gluten-free diet to avoid triggering symptoms.
# 2. Potato vodka is made from potatoes, which are naturally gluten-containing and not suitable for individuals with celiai disease.
# 3. Therefore, someone with Celiac Disease cannot consume potato vodka as it contains gluten.
# Final answer: No, someone who has celiac can't have potato vodkas because they contain gluten.
# Final statement:
# Final: No, someone
# --------------------
# final answer is: No
# pred is gold? False
# the q is Could Oprah Winfrey buy dozens of her staff Bugatti luxury cars? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Could Oprah Winfrey buy dozens of her staff Bugatti luxury cars?
# Reasoning:
# 1. To determine if Oprah Winfried can afford to buy dozens (more than 10) of her employees' Bugatti cars, we first need to know the cost of a single Bugatti car.
# 2. The average price of a Bugatti Veyron, which is one of the most expensive cars in the world, is around $2 million.
# 3. If we assume that each employee's car costs the same as the average Bugatti, then
# Final: Yes, Oprah
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Is Fiat Chrysler associated with Japanese cars? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Is Fiat Chrysler associated with Japanese cars?
# Reasoning:
# 1. Fiat Chrysler is a multinational automotive company based in the United States, known for manufacturing vehicles under various brands such as Jeep, Dodge, and Chrysler.
# 2. Fiat is an Italian brand, while Chrysler is an American brand.
# 3. Fiat has a significant presence in Europe, particularly in Italy, where it originated, but it does not have a strong presence in Japan.
# 4. Fiat's main market is primarily in North America, while Japanese automakers like Toyota,
# Final: No, Fiat
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is snoring a sign of good breathing while sleeping? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Is snoring a sign of good breathing while sleeping?
# Reasoning:
# 1. Snoring is often associated with obstructive sleep apnea, which is characterized by pauses in breathing during sleep.
# 2. Obstructive sleep Apnea (OSA) can lead to poor oxygenation and disrupt normal breathing patterns.
# 3. Therefore, snoring is not indicative of good respiratory function during sleep but rather a potential symptom of a more serious condition.
# Final answer: No, snorting is not a sign that one is breathing well while sleeping.
# Final: No, sn
# --------------------
# final answer is: No
# pred is gold? True
# the q is Does Darth Vader's character resemble Severus Snape? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Does Darth Vader's character resemble Severus Snape?
# Reasoning:
# 1. Both characters are complex and multi-dimensional, with a history of complex relationships and motivations.
# 2. Both have undergone significant character development throughout their respective stories, which adds to their complexity.
# 3. Both are known for their dark and brooding personalities, which can be seen in their actions and interactions with others.
# 4. Both share a tragic backstory that has shaped their characters and influenced their actions.
# 5. Despite these similarities, there are also notable differences
# Final: Yes, Darth
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Did Harvey Milk ever run for governor? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did Harvey Milk ever run for governor?
# Reasoning:
# 1. Harvey Milk was a prominent figure in the LGBTQ+ rights movement and served as the first openly gay elected official in California.
# 2. While he did not run for any political office at the federal level, he did run for various local and state positions, including city council and state assembly.
# 3. However, he never ran for governor of California, as that position is typically reserved for individuals who are not openly gay.
# 4. Therefore, it can be concluded
# Final: No, Harvey
# --------------------
# final answer is: No
# pred is gold? True
# the q is At a presentation about post traumatic stress disorder, would Ariana Grande be a topic of relevance? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: At a presentation about post traumatic stress disorder, would Ariana Grande be a topic of relevance?
# Reasoning:
# 1. Post-traumatic stress disorder (PTSD) is a mental health condition that can affect individuals who have experienced or witnessed a traumatic event.
# 2. Ariana Grand is a singer and songwriter known for her music, which often addresses personal experiences and emotions.
# 3. While Ariana's music may resonate with some individuals who are dealing with PTSD, it does not specifically address the disorder itself.
# 4. Therefore, while Ariana may be relevant in terms
# Final: No, Ari
# --------------------
# final answer is: No
# pred is gold? False
# the q is Should wool be hand washed only? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Should wool be hand washed only?
# Reasoning:
# 1. Wool is a delicate fabric that can easily shrink or become misshapen if not handled properly.
# 2. Hand washing allows for more control over the washing process, ensuring gentle treatment of the wool fibers.
# 3. Machine washing can be too harsh on wool, leading to damage and loss of its natural properties.
# 4. By hand washing, you can avoid the risk of damaging the wool and maintain its quality.
# 5. Therefore, it is generally recommended to
# Final: Yes, wool
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Is greed the most prevalent of the Seven Deadly Sins? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is greed the most prevalent of the Seven Deadly Sins?
# Reasoning:
# 1. Greed is often associated with a desire for wealth, power, and material possessions, which can lead to selfishness and disregard for others.
# 2. While other sins like envy, pride, and gluttony can also be problematic, greed is often considered the most destructive because it can drive individuals to prioritize their own interests over the well-being of others.
# Final answer: Yes, greed can be considered the "most prevalent" of the seven deadly sins
# Final: Yes, greed
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Is Antarctica a good location for Groundhog Day? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Is Antarctica a good location for Groundhog Day?
# Reasoning:
# 1. Groundhog Days is celebrated in the United States, specifically in Pennsylvania, where Punxsutawney Phil predicts the weather based on the behavior of groundhogs.
# 2. Antarctica is not part of the United Nations and does not have any cultural or historical significance related to Groundhog Week.
# 3. The climate in Antarctica is extremely cold and inhospitable, making it unsuitable for celebrating Groundhog Weeks.
# 4. There are no human settlements or communities
# Final: No, Antarctica
# --------------------
# final answer is: No
# pred is gold? True
# the q is Will a rock float in the atmosphere of Earth? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Will a rock float in the atmosphere of Earth?
# Reasoning:
# 1. To determine if a rock will float in Earth's atmosphere, we first need to consider its density. If the rock is less dense than the surrounding air, it will float; if it is denser, it sinks.
# 2. Next, we must examine the altitude at which the rock will be located. As altitude increases, atmospheric pressure decreases, which can affect the rock's buoyancy.
# 3. The composition of the rock also plays a role. Rocks with
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? True
# the q is Was historical Dracula from a town in Bucharest? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Was historical Dracula from a town in Bucharest?
# Reasoning:
# 1. The original Dracula novel was written by Bram Stoker, who was born in Ireland.
# 2. The character of Dracula is often associated with Transylvania, Romania, due to its historical and cultural significance in vampire folklore.
# 3. However, the town of Dracula in the novel is not based on any specific location; it is a fictional setting created by Stoker.
# Final answer: No, historical Dracula was not from a specific town in Romania.
# Final: No, historical
# --------------------
# final answer is: No
# pred is gold? True
# the q is Are Tom and Jerry featured in a ride at Disneyland? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Are Tom and Jerry featured in a ride at Disneyland?
# Reasoning:
# 1. The question asks if Tom andJerry are featured in any rides at Disneyland.
# 2. Tom and Mouse are indeed featured in the popular attraction, "Tom and Jerry's Toon Studio," which is a dark ride that takes guests on a journey through the cartoon characters' world.
# 3. Therefore, Tom and Mary are not featured in this ride.
# Final answer: No, Tom is featured in "Tom & Jerry'sToon Studio" but Mary is
# Final: No, Tom
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is a slime mold safe from cerebral palsy? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Is a slime mold safe from cerebral palsy?
# Reasoning:
# 1. Cerebral palsy is a neurological disorder that affects movement and coordination, not specifically related to slime molds.
# 2. Slime molds are single-celled organisms that do not possess a central nervous system or brain like humans do.
# 3. Therefore, the presence of cerebral palsiness does not impact the safety or behavior of slime mounds.
# Final answer: No, a slime mound is not safe from cerebal palsy.
#
# Textbook-
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Is Lord Voldemort associated with a staff member of Durmstrang? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is Lord Voldemort associated with a staff member of Durmstrang?
# Reasoning:
# 1. The first question asks if Lord Voldemort is associated with the character of Harry Potter.
# 2. Harry Potter is indeed associated with Lord Voldemort, as he is the main antagonist in the series.
# 3. The second question asks about the character Durmstratey.
# 4. Durmstring is not a real character in the Harry Potter series; it is a made-up name used by J.K. Rowling to refer to the staff member who
# Final: Yes, Lord
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Did Julius Caesar read books on Pharmacology? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did Julius Caesar read books on Pharmacology?
# Reasoning:
# 1. To determine if Julius Caesar was interested in pharmacology, we first need to establish whether he had access to books on the subject.
# 2. If he did have access to such books, it would indicate that he had an interest in pharmacological knowledge.
# 3. However, there is no historical evidence of Julius Caesar owning or having access to pharmacological texts.
# 4. Therefore, based on the lack of historical evidence, we can conclude that Julius Caesar did
# Final: No, Julius
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would a greyhound be able to outrun a greyhound bus? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would a greyhound be able to outrun a greyhound bus?
# Reasoning:
# 1. Greyhounds are known for their speed and agility, with an average top speed of 45 miles per hour (72 km/h).
# 2. Greyhound buses, on the other hand, typically travel at speeds of around 60-70 miles per hours (96-113 km/hour), which is significantly slower than a greyhounds' top speed.
# Final answer: No, a greydog would not be able outrun the greyhound buses.
# Final: No.
#
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can you use the T-Mobile tuesdays app if you aren't a T-Mobile customer? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can you use the T-Mobile tuesdays app if you aren't a T-Mobile customer?
# Reasoning:
# 1. The T-Mo Tuesdays app is designed specifically for T-mobile customers to receive exclusive deals and offers.
# 2. It is not available to non-T-Mobile customers, as it is a promotional tool for TMC's loyalty program.
# 3. Therefore, if you are not a TMC customer, you cannot access or use the app.
# Final answer: No, you can't use the tuesdies app if not a t-mobile customer
# Final: No, you
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can the theory of cultural hegemony explain global warming? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can the theory of cultural hegemony explain global warming?
# Reasoning:
# 1. The theory of hegemony suggests that dominant cultures shape and control the beliefs, values, and practices of subordinate cultures.
# 2. Global warming is a phenomenon that has been widely accepted by the scientific community as a result of human activities, particularly the burning of fossil fuels.
# 3. However, there are still some individuals and groups who deny or downplay the existence of global warming due to various reasons, such as political interests or ideological beliefs.
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Does a giant green lady stand in New York Harbor? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Does a giant green lady stand in New York Harbor?
# Reasoning:
# 1. The question asks if there is a giant statue of a green lady in New Yorks Harbor.
# 2. The Statue of Liberty, which is often referred to as Lady Liberty, is located on Liberty Island in New Jersey, not in New Orleans or New York City.
# 3. Therefore, there is no giant statue specifically of a "green lady" in New New York harbor.
# Final answer: No, there isn't a giant Green Lady statue in New
# Final: No, there
# --------------------
# final answer is: No
# pred is gold? False
# the q is Are the Great Lakes part of an international border? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Are the Great Lakes part of an international border?
# Reasoning:
# 1. The Great Lakes are located in North America, specifically in the United States and Canada.
# 2. The lakes are not directly adjacent to any international borders; they are surrounded by land within both countries.
# 3. While there may be some shared water boundaries between the two countries, these do not constitute an international boundary for the Great Lake region.
# Final answer: No, the Great lakes are primarily within the borders of the United states and Canada, and while there may
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? False
# the q is Did the first Duke of Valentinois play a key role in the Hundred Years' War? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did the first Duke of Valentinois play a key role in the Hundred Years' War?
# Reasoning:
# 1. The first Duke, Charles I, was born in 1415, which means he would not have been alive during the Hundred years' War (1337-1453).
# 2. The Hundred Years’ War was fought between England and France, and Charles I was a French nobleman, not an English one.
# 3. Therefore, Charles could not have played a key political or military role in this conflict.
# Final answer: No, the first Duchess
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can you save every HD episode of Game of Thrones on Samsung Galaxy A10e? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can you save every HD episode of Game of Thrones on Samsung Galaxy A10e?
# Reasoning:
# 1. The question asks if it is possible to save every episode of the TV series "Game of Thrones" on a Samsung Galaxy device.
# 2. To determine this, we need to consider whether the device has sufficient storage capacity to store all episodes.
# 3. Next, we must assess if the user has access to a reliable internet connection for streaming or downloading the episodes.
# 4. If the device does not have enough storage and the user cannot stream or
# Final: No, it
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would a Dodo hypothetically tower over Ma Petite? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Would a Dodo hypothetically tower over Ma Petite?
# Reasoning:
# 1. The Dodo is known to be a flightless bird, which means it lacks the ability to fly and therefore cannot reach heights comparable to other birds.
# 2. Ma Petites are small birds that typically do not grow very tall, as they are adapted for maneuverability in their environment rather than height.
# 3. Given these characteristics, it is clear that a Dodos' height would not surpass that of Ma Petits.
# Final answer: No, a Dod
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Does Lupita Nyongo have citizenship in paternal Family of Barack Obama's origin country? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Does Lupita Nyongo have citizenship in paternal Family of Barack Obama's origin country?
# Reasoning:
# 1. Lupita is a Mexican-American actress, which means she has dual citizenship in the United States and Mexico.
# 2. The question specifically asks about her citizenship in Barack Obama’s origin country, which is Kenya.
# 3. Lupito is not of Kenyan descent; she is of Mexican descent.
# 4. Therefore, Lupita does not have citizenship or ancestral ties to Kenya.
# Final answer: No, Lupito Nyongo does not hold citizenship
# Final: No, Lup
# --------------------
# final answer is: No
# pred is gold? False
# the q is Do most fans follow Katy Perry for gospel music? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Do most fans follow Katy Perry for gospel music?
# Reasoning:
# 1. Katy Perry is primarily known for her pop music, which includes genres like pop, dance-pop, and electronic music. Gospel music is a genre that focuses on religious themes and often incorporates elements of Christian worship.
# 2. While Katy Perry has released songs with gospel influences, such as "I Kissed a Girl" and "Teenage Dream," these songs are not considered gospel music in the traditional sense. They are more likely to be categorized as pop or contemporary Christian
# Final: No, most
# --------------------
# final answer is: No
# pred is gold? True
# the q is Did either Kublai Khan or his grandfather practice monogamy? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did either Kublai Khan or his grandfather practice monogamy?
# Reasoning:
# 1. Kublaid Khan was the grandson of Genghis Khan, who was known for his polygamous lifestyle.
# 2. However, there is no historical evidence to suggest that Kublay Khan practiced polygamy himself.
# 3. Kubla Khan's reign was marked by a focus on religious tolerance and cultural assimilation, which could indicate a preference for monogamy.
# Final answer: No, neither Kublays Khan nor his grandfather practiced polygamy.
# Final reasoning
# Final: No, there
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can you listen to the entire Itunes song catalog in one year? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can you listen to the entire Itunes song catalog in one year?
# Reasoning:
# 1. The Itunes store has over 1 million songs available for download.
# 2. Assuming an average of 10 songs downloaded per day, it would take approximately 100 days to download all the songs.
# 3. However, this calculation does not account for the time spent listening to the songs, which could vary greatly depending on individual preferences and habits.
# Final answer: No, it is not possible to listen to all the Itunes songs in one day or even in a year
# Final: No, it
# --------------------
# final answer is: No
# pred is gold? True
# the q is Did The Who have to cancel tours due to World War II? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did The Who have to cancel tours due to World War II?
# Reasoning:
# 1. The Who is a British rock band that formed in the 1960s.
# 2. World War I ended in 1918, while World WarII began in 1939.
# 3. The band was formed in 1964, which means they were not active during World WarI or II.
# 4. Therefore, The Who did not have to postpone or cancel tours during these wars.
# Final answer: No, The Was not required to cancel any tours due specifically to World WarsI
# Final: No
# Final
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can you drown in a Swan Lake performance? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can you drown in a Swan Lake performance?
# Reasoning:
# 1. Swan Lake is a ballet that involves dancers performing intricate movements and lifts, which may include water-based sequences.
# 2. Drowning occurs when a person's airway is submerged underwater, leading to the inability to breathe.
# 3. In a ballet performance, the dancers are trained professionals who know how to perform safely and avoid accidents.
# 4. The audience is seated in a theater, which provides a safe distance from any potential hazards.
#
# Given these
# Final: No, you
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is Ganymede in the Milky Way galaxy? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Is Ganymede in the Milky Way galaxy?
# Reasoning:
# 1. GanyMEDe is a moon of Jupiter, not a planet.
# 2. The Milky Way is a galaxy that contains our solar system, including Earth and its moons.
# 3. Therefore, GanyMede is not in the same galaxy as Earth or any other planet.
# Final answer: No, GANYMEDe does not exist in the milky way galaxy.
#
#
# To determine if Gany mede is in the galaxy, we
# Final: No, G
# --------------------
# final answer is: No
# pred is gold? False
# the q is Does walking across Amazonas put a person's life at risk? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Does walking across Amazonas put a person's life at risk?
# Reasoning:
# 1. Walking across Amazona is known to be dangerous due to the presence of wild animals, including venomous snakes and large predators like jaguars.
# 2. The dense rainforest environment can make navigation difficult, leading to getting lost or encountering hazardous terrain.
# 3. The lack of infrastructure and medical facilities in remote areas increases the risk of injury or illness.
# 4. The unpredictable weather conditions, such as heavy rainfall and flooding, can further exacerbate the dangers.
# Final: Yes, walking
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Can an elite runner circle the Pyrenees in one day? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can an elite runner circle the Pyrenees in one day?
# Reasoning:
# 1. The Pyrenee Mountains are a challenging terrain for runners due to their steep inclines and rugged paths.
# 2. Elite runners typically train extensively to build endurance and strength, which can help them navigate such terrains more efficiently.
# 3. However, even with extensive training, completing a full circuit of the Pyrennees in a single day is highly unlikely due to the physical demands of the route.
# Final answer: No, an elite athlete
# Final: No, an
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is 3D printing able to make adenovirus? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Is 3D printing able to make adenovirus?
# Reasoning:
# 1. Adenoviruses are complex biological structures that require specific components and arrangements to form.
# 2. 3D printers can create intricate shapes and structures, but they lack the ability to replicate the complex molecular interactions necessary for adenavirus formation.
# 3. Adenaviruses consist of genetic material (DNA) enclosed in a protein coat, which cannot be replicated by a 3D printer.
# 4. The replication process of adenviruses involves cellular machinery and
# Final: No, 3
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can the Department of Defense perform a solo? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can the Department of Defense perform a solo?
# Reasoning:
# 1. The Department of the Navy is a separate entity within the U.S. Department of Homeland Security, which focuses on maritime security and defense.
# 2. The U.N. Department for Peacekeeping Operations is responsible for maintaining peace and security in conflict zones worldwide.
# 3. The Federal Emergency Management Agency (FEMA) is an independent agency that coordinates disaster response efforts during emergencies.
# 4. The National Guard is a state-level military force that can be mobilized
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is the Easter Bunny popular in September? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Is the Easter Bunny popular in September?
# Reasoning:
# 1. The Easter Bunny is traditionally associated with Easter, which falls on a Sunday in April.
# 2. September is not typically associated with the celebration of Easter or the arrival of the Easter bunny.
# 3. Therefore, it is unlikely that the Easter Rabbit would be popular in the month of September.
# Final answer: No, the Easter rabbit is not popular in October.
#
# Textbook-level solution:
# To determine if the Easter Bunnies are popular in
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can depression be mistaken for laziness? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Can depression be mistaken for laziness?
# Reasoning:
# 1. Depression is a mental health condition characterized by persistent feelings of sadness, loss of interest, and low energy levels.
# 2. Laziness, on the other hand, refers to a lack of motivation or willingness to engage in activities.
# 3. While both conditions can lead to decreased productivity, laziness is often a temporary state of mind, whereas depression is a chronic condition that affects one's overall well-being.
# 4. Individuals with depression may experience difficulty finding pleasure
# Final: No, depression
# --------------------
# final answer is: No
# pred is gold? False
# the q is Did Operation Barbarossa or Barbarossa's last expedition succeed? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did Operation Barbarossa or Barbarossa's last expedition succeed?
# Reasoning:
# 1. Operation BarbarOSSa was a military operation launched by Nazi Germany in 1941, with the goal of invading the Soviet Union.
# 2. The operation was ultimately unsuccessful, as the German forces faced significant resistance from the Soviet army and suffered heavy casualties.
# 3. Barbarossas last expedition, which was a naval mission to the Arctic in 1942, also failed due to harsh weather conditions and the inability to locate the intended target.
# Final answer: No,
# Final: No, both
# --------------------
# final answer is: No
# pred is gold? True
# the q is Did the Royal Air Force fight in the Boxer Rebellion? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did the Royal Air Force fight in the Boxer Rebellion?
# Reasoning:
# 1. The Boxer rebellion was a violent anti-foreign movement that occurred in China from 1899 to 1901.
# 2. The Royal Air Forces (RAF) did not exist during this time, as it was established in 1918.
# 3. Therefore, the RAF did not participate in the conflict.
# Final answer: No, the Royal Aircraft Squadron did not fight in any conflicts before or after the Boxers Rebellion.
# Final reasoning: The RAF was not formed until
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would someone in CHE101 require a Maya Angelou book? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Would someone in CHE101 require a Maya Angelou book?
# Reasoning:
# 1. The student is enrolled in a course called "Introduction to Poetry," which suggests that they are studying poetry as a subject.
# 2. The question asks if they would need a specific book, indicating that there may be a particular text assigned for the course.
# 3. Since the course focuses on poetry, it is reasonable to assume that the required book would be related to this genre.
#
# Based on these points, it can be concluded that a student in CH
# Final: Yes, they
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Would the trees in Auburn, New York be changing colors in September? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Would the trees in Auburn, New York be changing colors in September?
# Reasoning:
# 1. Auburn, located in New York, experiences a temperate climate with distinct seasons.
# 2. In September, the weather in Auburn is typically cool and can vary depending on the region within the city.
# 3. The color change in trees is influenced by temperature, sunlight, and moisture levels, which can vary throughout the month.
# 4. Therefore, while some trees may start to change colors in late August or early September, others may not
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? False
# the q is Can a chess board be converted to a Shogi board? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can a chess board be converted to a Shogi board?
# Reasoning:
# 1. The first step is to understand the rules of Shogi, which are different from those of chess. Shogi has different pieces and movement patterns compared to chess.
# 2. Next, we need to consider the size of the board. Shogu boards are typically larger than chess boards, with dimensions of 10x10 or 12x12 squares.
# 3. Shigoku boards also have different markings and symbols compared to standard chess boards.
# 4. Additionally,
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? True
# the q is is the brain located in the torso? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: is the brain located in the torso?
# Reasoning:
# 1. The brain is a vital organ responsible for controlling various bodily functions and processes.
# 2. The torso refers to the central part of the body, which includes the abdomen and chest.
# 3. The location of the brain is typically described as being within the skull, which is not part of any specific region of the torso.
# 4. Therefore, based on these points, it is clear that the brain does not reside in the thoracic cavity or any other part
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is a platypus immune from cholera? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Is a platypus immune from cholera?
# Reasoning:
# 1. Platypuses are mammals, which means they have a similar immune system to other mammals.
# 2. Cholera is caused by the bacterium Vibrio cholerae, which primarily affects humans and some animals.
# 3. While platypuses can contract bacterial infections, there is no evidence to suggest that they are immune to choleria specifically.
# 4. Therefore, platypises are not immune to the effects of cholerae.
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Is a paleo dieter unlikely to color beverages green for St. Patrick's Day? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is a paleo dieter unlikely to color beverages green for St. Patrick's Day?
# Reasoning:
# 1. A paleo lifestyle focuses on consuming whole, unprocessed foods and avoiding grains, legumes, dairy, and processed sugars. This dietary approach does not typically include colored beverages like green drinks or sodas.
# 2. St. Patricks' Day is known for its traditional green drinks, such as Guinness or green beer, which are not part of the paleo dietary restrictions.
# 3. Therefore, a paleonutritionist would likely advise against consuming colored
# Final: Yes, a
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Do Shinto practitioners keep to a kosher diet? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Do Shinto practitioners keep to a kosher diet?
# Reasoning:
# 1. Shinto is a religion that originated in Japan and does not have specific dietary laws like kosher.
# 2. Kosher refers to dietary laws observed by Jewish people, which include restrictions on certain types of meat and the separation of meat from dairy products.
# 3. Shintos do not follow these dietary laws, as they are not based on religious texts or traditions.
# 4. Therefore, Shintoists do not adhere to a strict kosher diet.
# Final answer
# Final: No, Sh
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can a copy of The Daily Mirror sustain a campfire? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Can a copy of The Daily Mirror sustain a campfire?
# Reasoning:
# 1. The Daily Mirrors content is primarily focused on news and current events, which does not include information about fire safety or the use of firewood for camping.
# 2. The Mirror does not provide any guidance or instructions on how to safely start or maintain a camp fire.
# 3. Firewood is essential for a campground fire, but it is not mentioned in The DailyMirror's content.
# 4. Therefore, without specific knowledge about firewood and fire safety
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Does meat from cows fed only grass taste more like wild game? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Does meat from cows fed only grass taste more like wild game?
# Reasoning:
# 1. Cows that are fed only pasture-raised grass have a different diet compared to those raised in feedlots, which often include grains and other supplements.
# 2. The diet of the cow can affect the flavor and texture of the meat, as it influences the composition of fatty acids and other compounds.
# 3. Wild game, such as deer or elk, typically has a distinct flavor profile due to their natural diet of plants and vegetation.
# 4. Grass
# Final: Yes, meat
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Is a paraplegic suitable for conducting an orchestra? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Is a paraplegic suitable for conducting an orchestra?
# Reasoning:
# 1. Paraplegia refers to the loss of mobility in the lower body, which means that the individual may have difficulty with physical movements required for conducting, such as standing and gesturing.
# 2. Conducting an orchestra involves leading musicians through complex musical arrangements, which requires coordination, spatial awareness, and physical presence on stage.
# 3. While there are adaptive technologies available for individuals with disabilities to assist with conducting, these tools may not fully compensate for the limitations caused by
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Do people watching Coen brothers films in Guinea Bissau need subtitles? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Do people watching Coen brothers films in Guinea Bissau need subtitles?
# Reasoning:
# 1. The Coen Brothers are known for their unique and often complex storytelling style, which may not be easily understood by audiences unfamiliar with their work.
# 2. Guinea Bisseau is a country where the official language is Portuguese, which could potentially make it easier for viewers to understand the dialogue without subtitles.
# 3. However, there may still be cultural nuances or specific references in the films that could be challenging for non-native speakers to grasp.
# 4. Additionally,
# Final: While the official
# --------------------
# final answer is: No
# pred is gold? False
# the q is Is Cholera alive? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is Cholera alive?
# Reasoning:
# 1. Choleria is a bacterial infection caused by the bacterium Vibrio cholerae.
# 2. The bacterium is indeed alive, as it is a living organism that can reproduce and cause disease in humans.
# Final answer: Yes, Choleroa is alive.
#
# Q2: Does Choloroa have a specific host?
# A2: Yes. Chloro-a specifically infects humans, particularly those who consume contaminated food
# Final: Yes, Ch
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Can spiders help eggplant farmers control parasites? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Can spiders help eggplant farmers control parasites?
# Reasoning:
# 1. Spiders are known to prey on insects, including pests that can damage crops.
# 2. Some species of spiders, such as the jumping spider, are particularly effective at controlling pest populations.
# 3. By introducing spiders into their fields, eggplant growers may be able to reduce the need for chemical pesticides.
# 4. This could lead to a more sustainable and environmentally friendly approach to pest management.
# 5. However, it is important to consider the specific needs and
# Final: Yes, spiders
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Should someone prone to jealousy be in a polyamorous relationship? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Should someone prone to jealousy be in a polyamorous relationship?
# Reasoning:
# 1. Polyamory involves multiple romantic partners, which can lead to feelings of jealousy if one partner feels neglected or threatened by the others.
# 2. Jealousy is often rooted in fear of losing something valuable, and in a relationship with multiple partners, there is always a risk of that happening.
# 3. Polynomial relationships require open communication and trust, which may not be present in someone prone towards jealousy.
# 4. If someone struggles with jealousy, they may
# Final: No, someone
# --------------------
# final answer is: No
# pred is gold? True
# the q is Does Canada have a relationship with a monarch? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Does Canada have a relationship with a monarch?
# Reasoning:
# 1. The question asks if Canada has a relationship specifically with a monarchy, which is true. Canada is a constitutional monarchy, meaning it has a monarch as its head of state.
# 2. The next question asks about the monarch's role in Canada, which also confirms that the monarch holds a symbolic and ceremonial position in the country.
#
# Final answer: Yes, Canada does have a monarchy with the Queen of England as its monarch.
# Final reasoning: The monarch's presence
# Final: Yes, the
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Do onions have a form that resembles the inside of a tree? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Do onions have a form that resembles the inside of a tree?
# Reasoning:
# 1. Onions are root vegetables that grow underground, similar to how trees have roots.
# 2. The layers of an onion can be compared to the layers of bark on a tree trunk.
# 3. Both onions and trees have a protective outer layer that shields them from external elements.
# 4. The shape of an individual onion can resemble the overall shape of a small tree.
#
# Solution:
# Yes, onions do have a resemblance to the inside structure of a
# Final: Yes, onions
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Did Maroon 5 go on tour with Nirvana? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did Maroon 5 go on tour with Nirvana?
# Reasoning:
# 1. Maroon V5 is a band, not an individual artist.
# 2. Nirvana was a rock band that was active in the 1990s, while Maroon v5 formed in the 2000s.
# 3. The tour mentioned in the question occurred in 2009, which is after Nirvana's last tour.
# 4. Therefore, Maroon5 did not go on a tour with any specific band, including Nirvana.
# Final answer: No, Maroons 5 did not
# Final: No, Mar
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is Hermione Granger eligible for the Order of the British Empire? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Is Hermione Granger eligible for the Order of the British Empire?
# Reasoning:
# 1. The Order of Merit is awarded to individuals who have made significant contributions to the arts, sciences, or public service in the United Kingdom.
# 2. Hermione Granger is a fictional character from the Harry Potter series and does not exist in reality.
# 3. Therefore, she cannot be eligible for any real-world awards.
# Final answer: No, Hermione Granger cannot be awarded the Order or any other real-life honor.
#
# Textbook level solution:
# Final: No, Hermione
# --------------------
# final answer is: No
# pred is gold? True
# the q is Do Armenians tend to dislike System of a Down? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Do Armenians tend to dislike System of a Down?
# Reasoning:
# 1. The question asks if Armenians generally dislike System Of A Down, which implies that there is a negative sentiment towards the band among Armenians.
# 2. To determine if this sentiment exists, we can consider whether there are any specific incidents or events that have led to this perception.
# 3. If there are instances where System Of a Down has been criticized or negatively received by Armenians, it would support the idea that there may be a general dislike for the band.
# Final: Yes, Armen
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Could you drive from New England to a Sainsbury's? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Could you drive from New England to a Sainsbury's?
# Reasoning:
# 1. To determine if it is possible to drive from one location to another, we need to know the specific locations in question.
# 2. The question does not specify which locations are being referred to, so we cannot provide a definitive answer without that information.
# Final answer: No, I cannot drive from any location in New England directly to a location in the UK, including Sainsburys.
#
# Q1: Is there a direct road connection between New England
# Final: No, there
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would Glen Beck and Stephen Colbert be likely to tour together? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would Glen Beck and Stephen Colbert be likely to tour together?
# Reasoning:
# 1. Glen Beck is known for his conservative views, while Stephen Colbert is a liberal comedian. Their political ideologies are fundamentally different, which suggests that they may not align on certain topics or issues.
# 2. Both Glen Beck (as a talk show host) and Stephen Colella (as the host of The Colbert Report) have established themselves as prominent figures in their respective fields, but they have distinct audiences and followings. This indicates that they might not attract the same audience or
# Final: No, Glen
# --------------------
# final answer is: No
# pred is gold? True
# the q is Does actress Leila George lack the height to be a model? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Does actress Leila George lack the height to be a model?
# Reasoning:
# 1. The paragraph states that Leila is a model, which typically requires a certain height for specific types of modeling.
# 2. It also mentions that she is an actress, which may involve different physical attributes compared to modeling.
# 3. Therefore, it can be inferred that her height may not align with the requirements for modeling.
#
#
# Solution:
# Yes, actress LeILA George lacks the height required for modeling, as models often have specific height requirements for different types
# Final: Yes
# Final
# --------------------
# final answer is: Yes
# pred is gold? False
# ...
# Final answer: No, Jesus did go to church to teach about his teachings, but he did not receive formal
# Final: No, Jesus
# --------------------
# final answer is: No
# pred is gold? True
# the q is Could Lil Wayne's children ride in a Chevrolet Corvette ZR1 together? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Could Lil Wayne's children ride in a Chevrolet Corvette ZR1 together?
# Reasoning:
# 1. The Chevrolet Corvette is known for its high-performance and speed, which may not be suitable for young children.
# 2. Lil Wayne has three children, and it is unclear if they are old enough to safely operate or ride in such a fast vehicle.
# 3. Safety regulations typically require drivers to be at least 16 years old to legally drive a Corvette, which raises concerns about the age of Lil Wayne’s children.
#
# Given these considerations, it
# Final: No, Lil
# --------------------
# final answer is: No
# pred is gold? True
# the q is Are peaches best eaten when firm? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Are peaches best eaten when firm?
# Reasoning:
# 1. Peaches are typically harvested when they are ripe and soft, which is when they reach their peak flavor.
# 2. When peaches are firm, they may lack the sweetness and juiciness that comes with ripeness.
# 3. Therefore, it is generally recommended to eat peaches when they have softened to fully enjoy their taste and texture.
# Final answer: No, peaches should not be eaten when they're firm because they may not be as flavorful or
# Final: Yes, pe
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Was the AK-47 used in the Seven Years' War? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Was the AK-47 used in the Seven Years' War?
# Reasoning:
# 1. The AK- 47 was first produced in 1947, which is after the Seven Days' Battles of 1757, which marked the beginning of the Seven Year's War.
# 2. The Seven Years’ War ended in 1763, which means that the AK was not in production during this time.
# 3. Therefore, the AK did not play a role in the events leading up to or during the Seven years' War.
# Final answer: No, the
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is a krabby patty similar to a cheeseburger? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Is a krabby patty similar to a cheeseburger?
# Reasoning:
# 1. A krababy patty is made from ground beef, while a cheesecake is made with cream cheese and other ingredients.
# 2. Krabby Patty is a fictional food item from the TV show SpongeBob SquarePants, whereas cheeseburgers are a real-world food item.
# 3. Krabbies are aquatic creatures, while cheeseburger is a terrestrial animal.
# 4. Krabby Patties are typically served in a bun with
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Could the Austrian casualties from Seven Years' War fit in Indianapolis Motor Speedway? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Could the Austrian casualties from Seven Years' War fit in Indianapolis Motor Speedway?
# Reasoning:
# 1. The Austrian casualties are estimated to be around 10,000.
# 2. The Indianapolis Motor Speedway is a racetrack with a capacity of approximately 100,000 spectators.
# 3. To determine if the casualties could fit, we need to compare the number of casualties to the capacity of the racetracks.
# Final Answer: No, the Austrian fatalities from the Seven Years’ War cannot fit in the Indianapolis MotorSpeedway.
#
# Q2: How
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? False
# the q is Is it hard to get a BLT in Casablanca? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is it hard to get a BLT in Casablanca?
# Reasoning:
# 1. To determine if it is hard to find a BLOOM in CasaBlooms, we first need to clarify what you mean by "BLOOM." Are you referring to the restaurant or the specific dish?
# 2. If you are asking about the restaurant, CasaBloom is a popular eatery known for its BLT sandwiches, so it is relatively easy to find there.
# 3. Regarding the BLT dish, it is indeed common and widely
# Final: Yes, it
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Would a teacher still have their job if they called a black student an ape? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Would a teacher still have their job if they called a black student an ape?
# Reasoning:
# 1. The question is asking about the impact of calling a black child an ape on a teacher's job.
# 2. If the teacher calls a black pupil an ape, it would likely create a hostile and discriminatory environment for the student.
# 3. Such behavior could lead to disciplinary action against the teacher, including suspension or termination.
# 4. Additionally, the incident may result in legal consequences, as it violates anti-discrimination laws.
# 5. Therefore, the teacher would
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? True
# the q is Does ancient Olympics crown fail to hide tonsure? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Does ancient Olympics crown fail to hide tonsure?
# Reasoning:
# 1. The question asks if the ancient Olympic crown fails to hide a tonsure, which refers to the practice of shaving one's head as a religious or cultural tradition.
# 2. The ancient Olympic Games were held in ancient Greece and did not include the practice or recognition of tonsure.
# 3. The Olympic crown was a symbol of victory and honor, but it did not have any connection to religious practices such as tonsure that would be hidden beneath it.
# 4.
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? False
# the q is Did Linnaeus edit Darwin's draft of Origin of Species? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did Linnaeus edit Darwin's draft of Origin of Species?
# Reasoning:
# 1. Linnaean taxonomy was developed by Carl Linnaea, not Charles Darwin.
# 2. Linnean taxonomy is a system for classifying organisms based on their characteristics, while Darwin's work focused on the theory of evolution.
# 3. Linnea's taxonomy did not directly influence Darwin's ideas about natural selection and adaptation.
# 4. Linetta, a character in the novel "The Adventures of Huckleberry Finn" by Mark Twain, is
# Final: No, Lin
# --------------------
# final answer is: No
# pred is gold? True
# the q is Could a dandelion suffer from hepatitis? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Could a dandelion suffer from hepatitis?
# Reasoning:
# 1. Hepatitis is a viral infection that primarily affects the liver, causing inflammation and damage to liver cells.
# 2. Dandelions are plants and do not have a liver or a nervous system capable of contracting viruses.
# 3. Viruses require a host cell to replicate and cause infection, which dandelions lack.
# 4. Therefore, it is not possible for a dander to suffer from a viral disease like hepatitis.
# Final answer: No, a
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? True
# the q is Can you find a snow leopard in the Yucatan? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Can you find a snow leopard in the Yucatan?
# Reasoning:
# 1. The Yucatán Peninsula is located in Mexico, which is not the natural habitat of snow leopards. Snow leopets are found in the mountainous regions of Central Asia, particularly in countries like Mongolia and China.
# 2. Snow is not present in the climate of the YUCATAN, as it has a tropical climate characterized by high temperatures and humidity.
# 3. Snow does not exist in the region due to its warm climate, which does not
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is latitude required to determine the coordinates of an area? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is latitude required to determine the coordinates of an area?
# Reasoning:
# 1. Latitude is a measure of distance north or south of the equator, which helps in determining the position of a specific location on Earth's surface.
# 2. Longitude, on the other hand, measures distance east or west of the Prime Meridian, which is used to identify the position along the longitudinal axis.
# 3. Both latitude and longitude are necessary to pinpoint the exact coordinates of a place.
# 4. Without either latitude or longitude, it would
# Final: Yes, latitude
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Would Roman Gallic Wars army struggle to build the pyramids faster? !! and gold is: No
# first final Yes
# ---- RAW OUTPUT ----
# Q: Would Roman Gallic Wars army struggle to build the pyramids faster?
# Reasoning:
# 1. The Roman army was known for its advanced engineering and construction techniques, which allowed them to build large structures efficiently.
# 2. The pyramids were built by skilled laborers who followed specific architectural plans, indicating a level of organization and expertise.
# 3. The Romans had access to tools and resources that would have facilitated the construction process.
# 4. In contrast, the Roman Gallics, while having some military experience, lacked the same level of technological advancements and organizational skills as
# Final: Yes, the
# --------------------
# final answer is: Yes
# pred is gold? False
# the q is Is video surveillance of a room possible without an obvious camera or new item? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Is video surveillance of a room possible without an obvious camera or new item?
# Reasoning:
# 1. The question asks if it is possible to monitor a room without an obviously visible camera or a new item that could be used for surveillance.
# 2. If there are no cameras or new items, then it would be challenging to monitor the room effectively.
# 3. Therefore, without these elements, it is not possible to conduct video surveillance in this scenario.
# Final answer: No, it cannot be done.
#
# Complete detailed textbook-level solutions
# To determine if
# Final: No, it
# --------------------
# final answer is: No
# pred is gold? False
# the q is Was Mother Theresa a follower of atheism? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Was Mother Theresa a follower of atheism?
# Reasoning:
# 1. Mother Teresa was known for her dedication to serving the poor and marginalized, which aligns with religious teachings that emphasize compassion and service to others.
# 2. She received the Nobel Peace Prize in 1979, which is often associated with individuals who promote peace and humanitarian efforts, rather than atheism.
# 3. Mother Theresa's public statements and writings consistently emphasized the importance of faith and spirituality in addressing social issues.
# 4. Her work focused on alleviating suffering and promoting love and
# Final: No, Mother
# --------------------
# final answer is: No
# pred is gold? True
# the q is Would a German Shepherd be welcome in an airport? !! and gold is: Yes
# first final No
# ---- RAW OUTPUT ----
# Q: Would a German Shepherd be welcome in an airport?
# Reasoning:
# 1. German Shepherds are known for their protective nature and can be trained as service dogs, which may make them suitable for certain airport security roles.
# 2. However, they are generally not considered to be the most popular breed for service dog work, as other breeds like Golden Retrievers and Labrador Retrieves are more commonly used.
# 3. Additionally, while some airports may have specific programs or policies regarding service animals, there is no universal standard for all airports
# Final: No, a
# --------------------
# final answer is: No
# pred is gold? False
# the q is Are all characters in Legend of Robin Hood fictional? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Are all characters in Legend of Robin Hood fictional?
# Reasoning:
# 1. The character of Robin is a historical figure who lived during the medieval period, specifically in the 13th century.
# 2. Robin Hood's existence is well-documented in folklore and literature from that time, including works by various authors such as Sir Thomas Malory and Walter Scott.
# 3. Therefore, Robin Hood is not a fictional character but rather a historical persona.
# 4. In contrast, other characters in the legend, such as Maid Marian or Little John
# Final: No, not
# --------------------
# final answer is: No
# pred is gold? True
# the q is Has Alan Greenspan lived through at least a baker's dozen of president's? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Has Alan Greenspan lived through at least a baker's dozen of president's?
# Reasoning:
# 1. A baker'sdozen refers to thirteen items, which is more than twelve.
# 2. Alan Greenspans presidency lasted from January 20, 1981, to January 20th, 2001, which means he served for 20 years.
# 3. To determine if he has lived through a baker’s dozen of presidents, we need to calculate how many presidents there have been in total during that time.
# 4. There have been 44 presidents since the founding of the United
# Final: Yes, Alan
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Does Sam Harris worship Shiva? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Does Sam Harris worship Shiva?
# Reasoning:
# 1. Sam Harris is a philosopher and author known for his work in atheism and critical thinking.
# 2. Shiva is a Hindu deity often associated with destruction and transformation, which may not align with Harris's philosophical beliefs.
# 3. Harris has expressed skepticism towards religious beliefs and practices, indicating that he does not worship any specific deity.
# 4. Given these points, it can be concluded that Harris does not actively worship Shiva.
# Final answer: No, Sam Harris does worship
# Final: No, Sam
# --------------------
# final answer is: No
# pred is gold? True
# the q is Does Robert De Niro use a microscope at work? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Does Robert De Niro use a microscope at work?
# Reasoning:
# 1. Robert DeNiro is known for his roles in various films, including "The Godfather" and "Goodfellas."
# 2. These films are primarily focused on the criminal underworld and do not involve scientific or laboratory settings.
# 3. Microscopes are commonly used in scientific research, medical fields, and educational institutions, but not in the context of filmmaking.
# Final answer: No, Robert De Natiro does not use a microphone at work.
# Final: No, he
# --------------------
# final answer is: No
# pred is gold? True
# the q is Is Disney associated with Los Angeles County? !! and gold is: Yes
# first final Yes
# ---- RAW OUTPUT ----
# Q: Is Disney associated with Los Angeles County?
# Reasoning:
# 1. The first question asks if Disney is a theme park located in Los Angeles. Yes, Disneyland and Disney California Adventure Park are both theme parks in Los Angelinos County.
# 2. The second question asks about the location of Disney's headquarters. Disney's corporate headquarters are located in Burbank, which is also in Los Angles County.
#
# Given that Disney has theme parks and its headquarters are in Los Angels County, it can be concluded that Disney is indeed associated
# Final: Yes, Disney
# --------------------
# final answer is: Yes
# pred is gold? True
# the q is Did occupants of Vellore Fort need to defend themselves from Grizzly Bears? !! and gold is: No
# first final No
# ---- RAW OUTPUT ----
# Q: Did occupants of Vellore Fort need to defend themselves from Grizzly Bears?
# Reasoning:
# 1. The Vellorean Fort was built in the 16th century, which is before the time when Grizzly bears were present in India. Grizzly bear populations were primarily found in North America during that period.
# 2. Grizzlies are not native to India; they are found in the northern regions of North America, particularly in Alaska and Canada.
# 3. The fort's location in southern India does not align with the natural habitat of Grizzly Bear populations.
# Final: No, the
# --------------------
# final answer is: No
# pred is gold? True
# [DEV ACC] 0.690  (69/100)
# [OK] Wrote predictions to: /content/drive/MyDrive/LLM_Models/cot_student_out__preds.json

# %% [markdown]
# ### Notes & Tips
# - **Faithfulness to article**: This trains the student to *produce* CoT+Final from only the question (no rationale conditioning at input).
# - **Filtering**: Only teacher generations that match the gold label are kept (strongly recommended).
# - **Budget**: Lower `MAX_TRAIN_SAMPLES` if teacher API cost is a concern. StrategyQA CoTs are short; `MAX_SEQ_LEN=256` is usually enough.
# - **Your student model**: Replace `BASE_MODEL` with the exact model you use.
# - **Teacher**: Swap to your preferred provider if not using OpenAI (`TEACHER_PROVIDER="dummy"` lets you dry-run the pipeline).
